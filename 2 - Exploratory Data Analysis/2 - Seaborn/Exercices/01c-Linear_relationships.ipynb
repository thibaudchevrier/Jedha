# %% [markdown]
# n IBM_HR_ATTRITION.csv# Visualization of a linear relationship
#
# Working on <a href="https://full-stack-bigdata-datasets.s3.eu-west-3.amazonaws.com/Data+visualisation+et+collaboration/M03.D02/IBM_HR_ATTRITION.csv" target="_blank"> ```IBM_HR_ATTRITION.csv```</a>.

# %% [markdown]
# 1. Import usual libraries ```pandas```, ```seaborn``` and ```statsmodels```. This last one is important to use ```lmplot()``` fucntion. Also import the dataset

# %%
import seaborn as sns
import pandas as pd
import statsmodels as sm

# %%
datas = pd.read_csv("../../src/IBM_HR_ATTRITION.csv")

# %%
datas.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# 2. We would like to know the probability of leaving the business in relation to the distance from home. Use ```lmplot()``` to view this.

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1426         try:
# -> 1427             x = float(x)
#    1428         except ValueError:
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1430             try:
# -> 1431                 x = complex(x)
#    1432             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f939e9722317> in <module>
# ...

# %% [markdown]
# 3. Try to resolve this error to be able to use ```lmplot```.
#
# **Tip:**
#
# You can use ```apply(lambda x:)```
#
# If you have this kind of error: _No module named 'statsmodels'_ let's do a ```pip install statsmodels```

# %% [markdown]
# 3. Try it this time with the number of years spent with the Manager ```YearsWithCurrManager```, what can you conclude?

# %% [markdown]
# 4. Attempt to look at other variables, including ```YearsAtCompany```

# %% [markdown]
# 5. Let's have a look with ```Age```

# %% [markdown]
# 6. To finish with ```Education```
