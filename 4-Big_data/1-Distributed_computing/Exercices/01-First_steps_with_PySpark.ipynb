# %% [markdown]
# # First steps with PySpark

# %% [markdown]
# ## Learning objectives
#
# - Get familiar with PySpark RDDs
# - Become imbued with the concept of lazyness

# %%
import pyspark

spark = (pyspark.sql.SparkSession.builder \
         .master('local') \
         .appName('Introduction to PySpark') \
         .config("spark.some.config.option", "some-value") \
         .getOrCreate())

sc = spark.sparkContext
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# We need a S3 filepath
S3_RESOURCE = 's3'
SCHEME = 's3a'
# TODO: assign a BUCKET_NAME and PREFIX
BUCKET_NAME = ''
PREFIX = ''
FILENAME = 'tears_in_rain.txt'

# %%
# This is just a utility function
def get_s3_path(key, bucket_name=BUCKET_NAME, scheme=SCHEME):
    return f"{scheme}://{bucket_name}/{key}"

# %%
### BEGIN STRIP ###
# This is required for local work

### END STRIP ###

# %%
# TODO: Load the file from `filepath` into a PySpark RDD
### BEGIN STRIP ###
from pathlib import Path

path = Path("FileStore", "shared_uploads", "thibaudchevrier@gmail.com", "tears_in_rain.txt")
tears_in_rain_rdd = sc.textFile(str(path))

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TODO: print out text_file
### BEGIN STRIP ###

tears_in_rain_rdd.collect()

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[37]: [&#34;I&#39;ve seen things you people wouldn&#39;t believe. &#34;,
#  &#39;Attack ships on fire off the shoulder of Orion. &#39;,
#  &#39;I watched C-beams glitter in the dark near the Tannhäuser Gate. &#39;,
#  &#39;All those moments will be lost in time, like tears in rain. &#39;,
#  &#39;Time to die.&#39;]</div>

# %% [markdown]
# That doesn't tell us much, how would you do to see the first 3 elements of this RDD?

# %% [markdown]
# What's the type of `text_file`?

# %%
# TODO: check the type of `text_file`
### BEGIN STRIP ###

type(tears_in_rain_rdd)

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: pyspark.rdd.RDD</div>

# %% [markdown]
# It's a PySpark `RDD`. It means we can call **actions** on it and it will return a result.
#
# We'll try a first one, `.take(...)`.

# %%
# TODO: take the first 3 elements of the RDD `text_file`
### BEGIN STRIP ###

tears_in_rain_rdd.take(3)

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: [&#34;I&#39;ve seen things you people wouldn&#39;t believe. &#34;,
#  &#39;Attack ships on fire off the shoulder of Orion. &#39;,
#  &#39;I watched C-beams glitter in the dark near the Tannhäuser Gate. &#39;]</div>

# %% [markdown]
# And now, another one, we want the results to be all elements of the `rdd`.

# %%
# TODO: collect all elements of `text_file`
### BEGIN STRIP ###

tears_in_rain_rdd.collect()

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: [&#34;I&#39;ve seen things you people wouldn&#39;t believe. &#34;,
#  &#39;Attack ships on fire off the shoulder of Orion. &#39;,
#  &#39;I watched C-beams glitter in the dark near the Tannhäuser Gate. &#39;,
#  &#39;All those moments will be lost in time, like tears in rain. &#39;,
#  &#39;Time to die.&#39;]</div>

# %% [markdown]
# How many lines are there in `text_file`?

# %%
# TODO: count the number of lines in `text_file`
### BEGIN STRIP ###

len(tears_in_rain_rdd.collect())

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: 5</div>

# %% [markdown]
# What's the length of each sentence?

# %%
# TODO: call `.map(...)` on your rdd and give it a function that computes the lenght of a string: `lineLengths`
#
# NOTE: the end of previous line, ": `LineLenghts`" is how you should name your result variable
#
### BEGIN STRIP ### 

line_length = tears_in_rain_rdd.map(lambda line: len(line))

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TODO: take the first 3 elements of lineLengths
### BEGIN STRIP ###

line_length.take(3)

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: [46, 48, 64]</div>

# %%
# TODO: collect all elements of lineLenghts
### BEGIN STRIP ###

line_length.collect()

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: [46, 48, 64, 60, 12]</div>

# %% [markdown]
# What's the average length?

# %%
# TODO: compute the average value of `lineLengths`: `avgLength`
### BEGIN STRIP ###

avg_length = line_length.mean()

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TODO: what's the type of `avgLength`? Print it out.
### BEGIN STRIP ###

type(avg_length)

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: float</div>

# %%
# TODO: print out `avgLength`
### BEGIN STRIP ###
print(avg_length)
### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">46.0
# </div>

# %% [markdown]
# Now we want to compute the total length of the document

# %%
# TODO: compute the sum of all `lineLengths`: `totalLength`
### BEGIN STRIP ###
total_length = line_length.sum()
### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# TODO: what's the type of `totalLength`
### BEGIN STRIP ###
type(total_length)
### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[31]: int</div>

# %%
# TODO: print out `totalLength`
### BEGIN STRIP ###
print(total_length)
### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">230
# </div>

# %% [markdown]
# ## Bonus: another way to compute the sum would be to use a `reducer`
# This is a step exercise to get you prepare for the next (optional) assignment.
#
# Your goal is to compute the sum of lineLenghts, just like we did, but this time using `.reduce(...)`.
# Here is the link to the [documentation](https://spark.apache.org/docs/latest/api/python/pyspark.html#pyspark.RDD.reduce).

# %%
# Try to compute the total sum, but this time using `.reduce(...)`
### BEGIN STRIP ###
from operator import add
line_length.reduce(add)
### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: 230</div>
