# %% [markdown]
# # Data selection for `songs` analysis
#
# In this notebook, we will load the data we pushed previously onto Redshift and perform columns selection.

# %%
# TODO: set up your Redshift parameters
# NOTE: again, this is not the appropriate way to this... You should, at least, use environment variables for the password
REDSHIFT_USER = ''
REDSHIFT_PASSWORD = ''
REDSHIFT_DB = ''
REDSHIFT_HOST = ''
REDSHIFT_PORT = 5439

REDSHIFT_TABLE = 'youtube_data'
REDSHIFT_IAM_ROLE = ''
REDSHIFT_TEMP_DIR = ''

redshift_uri = (f'jdbc:redshift://{REDSHIFT_HOST}:{REDSHIFT_PORT}/{REDSHIFT_DB}?user={REDSHIFT_USER}&password={REDSHIFT_PASSWORD}'
                '&ssl=true&sslfactory=com.amazon.redshift.ssl.NonValidatingFactory')

# %%
# TODO: Load the data from Redshift into a PySpark DataFrame: `songs_raw`
### BEGIN STRIP ###

### END STRIP ###

# %%
# TODO: Load the data from Redshift into a PySpark DataFrame: `songs_raw`
# NOTE: Then, perform the usual checks
### BEGIN STRIP ###

### END STRIP ###
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contentDetails_caption</th>
#       <th>contentDetails_contentRating_ytRating</th>
#       <th>contentDetails_definition</th>
#       <th>contentDetails_dimension</th>
#       <th>contentDetails_duration</th>
#       <th>contentDetails_licensedContent</th>
#       <th>contentDetails_projection</th>
#       <th>etag</th>
#       <th>id</th>
#       <th>kind</th>
#       <th>snippet_categoryId</th>
#       <th>snippet_channelId</th>
#       <th>snippet_channelTitle</th>
#       <th>snippet_defaultAudioLanguage</th>
#       <th>snippet_defaultLanguage</th>
#       <th>snippet_liveBroadcastContent</th>
#       <th>snippet_publishedAt</th>
#       <th>snippet_thumbnails_default_height</th>
#       <th>snippet_thumbnails_default_url</th>
#       <th>snippet_thumbnails_default_width</th>
#       <th>snippet_thumbnails_high_height</th>
#       <th>snippet_thumbnails_high_url</th>
#       <th>snippet_thumbnails_high_width</th>
#       <th>snippet_thumbnails_maxres_height</th>
#       <th>snippet_thumbnails_maxres_url</th>
#       <th>snippet_thumbnails_maxres_width</th>
#       <th>snippet_thumbnails_medium_height</th>
#       <th>snippet_thumbnails_medium_url</th>
#       <th>snippet_thumbnails_medium_width</th>
#       <th>snippet_thumbnails_standard_height</th>
#       <th>snippet_thumbnails_standard_url</th>
#       <th>snippet_thumbnails_standard_width</th>
#       <th>snippet_title</th>
#       <th>statistics_commentCount</th>
#       <th>statistics_dislikeCount</th>
#       <th>statistics_favoriteCount</th>
#       <th>statistics_likeCount</th>
#       <th>statistics_viewCount</th>
#       <th>status_embeddable</th>
#       <th>status_license</th>
#       <th>status_privacyStatus</th>
#       <th>status_publicStatsViewable</th>
#       <th>status_uploadStatus</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>false</td>
#       <td>None</td>
#       <td>hd</td>
#       <td>2d</td>
#       <td>PT4M4S</td>
#       <td>True</td>
#       <td>rectangular</td>
#       <td>"p4VTdlkQv3HQeTEaXgvLePAydmU/dNtmWojm0YkTi6jsl...</td>
#       <td>lpmGsDO3y1A</td>
#       <td>youtube#video</td>
#       <td>24</td>
#       <td>UCvbWEMiuM3B4EGiHSSlXSNg</td>
#       <td>► URBAN LATIN</td>
#       <td>en-US</td>
#       <td>None</td>
#       <td>none</td>
#       <td>2013-10-30T13:20:22.000Z</td>
#       <td>90</td>
#       <td>https://i.ytimg.com/vi/lpmGsDO3y1A/default.jpg</td>
#       <td>120</td>
#       <td>360</td>
#       <td>https://i.ytimg.com/vi/lpmGsDO3y1A/hqdefault.jpg</td>
#       <td>480</td>
#       <td>NaN</td>
#       <td>None</td>
#       <td>NaN</td>
#       <td>180</td>
#       <td>https://i.ytimg.com/vi/lpmGsDO3y1A/mqdefault.jpg</td>
#       <td>320</td>
#       <td>480.0</td>
#       <td>https://i.ytimg.com/vi/lpmGsDO3y1A/sddefault.jpg</td>
#       <td>640.0</td>
#       <td>Chacal y Yakarta - Linda (Official Video)</td>
#       <td>42</td>
#       <td>102</td>
#       <td>0</td>
#       <td>2586</td>
#       <td>737628</td>
#       <td>True</td>
#       <td>youtube</td>
#       <td>public</td>
#       <td>True</td>
#       <td>processed</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>false</td>
#       <td>None</td>
#       <td>hd</td>
#       <td>2d</td>
#       <td>PT3M52S</td>
#       <td>False</td>
#       <td>rectangular</td>
#       <td>"p4VTdlkQv3HQeTEaXgvLePAydmU/8GtCYISbZwV9wsxi8...</td>
#       <td>YEEhwQApRYg</td>
#       <td>youtube#video</td>
#       <td>10</td>
#       <td>UCqpYDr3SrHa6MIm_gBd0O1Q</td>
#       <td>Julia Clement</td>
#       <td>None</td>
#       <td>None</td>
#       <td>none</td>
#       <td>2013-02-17T11:38:14.000Z</td>
#       <td>90</td>
#       <td>https://i.ytimg.com/vi/YEEhwQApRYg/default.jpg</td>
#       <td>120</td>
#       <td>360</td>
#       <td>https://i.ytimg.com/vi/YEEhwQApRYg/hqdefault.jpg</td>
#       <td>480</td>
#       <td>720.0</td>
#       <td>https://i.ytimg.com/vi/YEEhwQApRYg/maxresdefau...</td>
#       <td>1280.0</td>
#       <td>180</td>
#       <td>https://i.ytimg.com/vi/YEEhwQApRYg/mqdefault.jpg</td>
#       <td>320</td>
#       <td>480.0</td>
#       <td>https://i.ytimg.com/vi/YEEhwQApRYg/sddefault.jpg</td>
#       <td>640.0</td>
#       <td>Desire Claire Denamur (BO Tiger Lily)</td>
#       <td>13</td>
#       <td>1</td>
#       <td>0</td>
#       <td>112</td>
#       <td>19478</td>
#       <td>True</td>
#       <td>youtube</td>
#       <td>public</td>
#       <td>True</td>
#       <td>processed</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>false</td>
#       <td>None</td>
#       <td>hd</td>
#       <td>2d</td>
#       <td>PT3M24S</td>
#       <td>True</td>
#       <td>rectangular</td>
#       <td>"p4VTdlkQv3HQeTEaXgvLePAydmU/AedTOI1-EntjnxhVh...</td>
#       <td>nSpBs1ghyoo</td>
#       <td>youtube#video</td>
#       <td>10</td>
#       <td>UCemJxBoqNChIXZjd5MjBqpg</td>
#       <td>Ace Records Ltd</td>
#       <td>None</td>
#       <td>None</td>
#       <td>none</td>
#       <td>2014-08-19T09:24:23.000Z</td>
#       <td>90</td>
#       <td>https://i.ytimg.com/vi/nSpBs1ghyoo/default.jpg</td>
#       <td>120</td>
#       <td>360</td>
#       <td>https://i.ytimg.com/vi/nSpBs1ghyoo/hqdefault.jpg</td>
#       <td>480</td>
#       <td>720.0</td>
#       <td>https://i.ytimg.com/vi/nSpBs1ghyoo/maxresdefau...</td>
#       <td>1280.0</td>
#       <td>180</td>
#       <td>https://i.ytimg.com/vi/nSpBs1ghyoo/mqdefault.jpg</td>
#       <td>320</td>
#       <td>480.0</td>
#       <td>https://i.ytimg.com/vi/nSpBs1ghyoo/sddefault.jpg</td>
#       <td>640.0</td>
#       <td>Gil Scott-Heron - Home Is Where the Hatred Is ...</td>
#       <td>338</td>
#       <td>120</td>
#       <td>0</td>
#       <td>7027</td>
#       <td>582259</td>
#       <td>True</td>
#       <td>youtube</td>
#       <td>public</td>
#       <td>True</td>
#       <td>processed</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>false</td>
#       <td>None</td>
#       <td>sd</td>
#       <td>2d</td>
#       <td>PT2M27S</td>
#       <td>False</td>
#       <td>rectangular</td>
#       <td>"p4VTdlkQv3HQeTEaXgvLePAydmU/tOCk-WNQUdP8u11UC...</td>
#       <td>5PzL8aL6jtI</td>
#       <td>youtube#video</td>
#       <td>10</td>
#       <td>UCJ5o5sPuKn9gYK6zu4EZD_g</td>
#       <td>GOTHGAM08</td>
#       <td>None</td>
#       <td>None</td>
#       <td>none</td>
#       <td>2008-12-21T18:32:31.000Z</td>
#       <td>90</td>
#       <td>https://i.ytimg.com/vi/5PzL8aL6jtI/default.jpg</td>
#       <td>120</td>
#       <td>360</td>
#       <td>https://i.ytimg.com/vi/5PzL8aL6jtI/hqdefault.jpg</td>
#       <td>480</td>
#       <td>NaN</td>
#       <td>None</td>
#       <td>NaN</td>
#       <td>180</td>
#       <td>https://i.ytimg.com/vi/5PzL8aL6jtI/mqdefault.jpg</td>
#       <td>320</td>
#       <td>NaN</td>
#       <td>None</td>
#       <td>NaN</td>
#       <td>Tomorrow (annie) Lyrics</td>
#       <td>6210</td>
#       <td>4383</td>
#       <td>0</td>
#       <td>83460</td>
#       <td>18174533</td>
#       <td>True</td>
#       <td>youtube</td>
#       <td>public</td>
#       <td>True</td>
#       <td>processed</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>false</td>
#       <td>None</td>
#       <td>hd</td>
#       <td>2d</td>
#       <td>PT2M42S</td>
#       <td>True</td>
#       <td>rectangular</td>
#       <td>"p4VTdlkQv3HQeTEaXgvLePAydmU/IpXLffRBeMw_fDWwl...</td>
#       <td>wYP1slJayuw</td>
#       <td>youtube#video</td>
#       <td>10</td>
#       <td>UCrlNi8Z5TXfWJf4psK76KWw</td>
#       <td>Délicieuse Musique</td>
#       <td>None</td>
#       <td>None</td>
#       <td>none</td>
#       <td>2015-10-21T14:13:03.000Z</td>
#       <td>90</td>
#       <td>https://i.ytimg.com/vi/wYP1slJayuw/default.jpg</td>
#       <td>120</td>
#       <td>360</td>
#       <td>https://i.ytimg.com/vi/wYP1slJayuw/hqdefault.jpg</td>
#       <td>480</td>
#       <td>NaN</td>
#       <td>None</td>
#       <td>NaN</td>
#       <td>180</td>
#       <td>https://i.ytimg.com/vi/wYP1slJayuw/mqdefault.jpg</td>
#       <td>320</td>
#       <td>480.0</td>
#       <td>https://i.ytimg.com/vi/wYP1slJayuw/sddefault.jpg</td>
#       <td>640.0</td>
#       <td>Mounika. - Marie Laforet (Tu

# %% [markdown]
# **43 columns, that's quite many columns!** It would take time to explore all of this.
# The goal of this notebook is too quickly scan through the columns and make a selection of some interesting ones that we will explore first.
#
# We will first get a sense of the different values in each column. Since we will do this for each of the 43 columns, we will write a function that we can then call on all columns.
#
# Our function will be called `value_counts` and takes 2 parameters:
# - `df`: a PySpark DataFrame
# - `col_name`: the name of the column for which we want to count the columns
#
# This function should return the count of each distinct values of the column as a PySpark DataFrame.

# %%
# TODO: Create the function `value_counts` as per the instructions
### BEGIN STRIP ###

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# We're now ready to use our function over all columns of `songs_raw`.

# %%
# TODO: Iterate over each column of `songs_raw` and `.show()` the results of calling `value_counts`
### BEGIN STRIP ###

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------------+------+
# contentDetails_caption| count|
# +----------------------+------+
#                  false|506644|
#                   true|  5980|
# +----------------------+------+
#
# +-------------------------------------+------+
# contentDetails_contentRating_ytRating| count|
# +-------------------------------------+------+
#                                  null|511037|
#                       ytAgeRestricted|  1587|
# +-------------------------------------+------+
#
# +-------------------------+------+
# contentDetails_definition| count|
# +-------------------------+------+
#                        sd|260168|
#                        hd|252456|
# +-------------------------+------+
#
# +------------------------+------+
# contentDetails_dimension| count|
# +------------------------+------+
#                       2d|512610|
#                       3d|    14|
# +------------------------+------+
#
# +-----------------------+-----+
# contentDetails_duration|count|
# +-----------------------+-----+
#                  PT4M1S| 3566|
#                 PT3M31S| 3425|
#                 PT3M41S| 3283|
#                 PT3M51S| 3224|
#                 PT3M46S| 3159|
#                 PT3M45S| 3051|
#                 PT3M59S| 3015|
#                  PT4M6S| 2983|
#                 PT3M36S| 2974|
#                 PT3M38S| 2965|
#                 PT3M56S| 2927|
#                 PT3M34S| 2908|
#                 PT3M55S| 2903|
#                 PT3M37S| 2892|
#                 PT3M52S| 2889|
#                 PT3M43S| 2881|
#                 PT3M49S| 2834|
#                 PT3M42S| 2823|
#                 PT3M47S| 2822|
#                 PT3M35S| 2821|
# +-----------------------+-----+
# only showing top 20 rows
#
# +------------------------------+------+
# contentDetails_licensedContent| count|
# +------------------------------+------+
#                          false|385644|
#                           true|126980|
# +------------------------------+------+
#
# +-------------------------+------+
# contentDetails_projection| count|
# +-------------------------+------+
#               rectangular|512578|
#                       360|    46|
# +-------------------------+------+
#
# +--------------------+-----+
#                 etag|count|
# +--------------------+-----+
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# &#34;p4VTdlkQv3HQeTEa...|    1|
# +--------------------+-----+
# only showing top 20 rows
#
# +-----------+-----+
#          id|count|
# +-----------+-----+
# juMRLDpxMqA|    1|
# VSecjqcO3Jk|    1|
# 5KKMc5eAhcM|    1|
# 9AKagm0OPUo|    1|
# cb61AVsxD34|    1|
# ZO6giM9UAv0|    1|
# 1M54Z8tFPI4|    1|
# _xODu-sRvAs|    1|
# oGe6GQmLUF4|    1|
# imTDWIZwEDU|    1|
# 3KHoLogLoGg|    1|
# IyFlca2mIgU|    1|
# p00RA4tK7CI|    1|
# cbDR1It_Tpg|    1|
# W4nwwKLHr4s|    1|
# gC2G9ZVb8X4|    1|
# U5fNFhd1mrM|    1|
# yNdDyac85g0|    1|
# 789A-pJQJao|    1|
# SqC5LdxROwk|    1|
# +-----------+-----+
# only showing top 20 rows
#
# +-------------+------+
#          kind| count|
# +-------------+------+
# youtube#video|512624|
# +-------------+------+
#
# +------------------+------+
# snippet_categoryId| count|
# +------------------+------+
#                 10|445421|
#                 22| 28936|
#                 24| 21151|
#                  1|  6228|
#                 23|  2049|
#                 20|  2041|
#                 27|  1553|
#                 25|   947|
#                 29|   744|
#                 17|   712|
#                  2|   687|
#                 26|   674|
#                 19|   664|
#                 28|   478|
#                 15|   333|
#                 44|     3|
#                 30|     2|
#                 43|     1|
# +------------------+------+
#
# +--------------------+-----+
#    snippet_channelId|count|
# +--------------------+-----+
# UCPkgp7lzgNnDMvMv...| 1060|
# UCXIyz409s7bNWVcM...|  871|
# UC6qQOTx9LuKMC5p2...|  854|
# UC5nc_ZtjKW1htCVZ...|  852|
# UCGBpxWJr9FNOcFYA...|  839|
# UC3I2GFN_F8WudD_2...|  824|
# UCpDJl2EmP7Oh90Vy...|  793|
# UCweOkPb1wVVH0Q0T...|  579|
# UCQT-h--PG_pq2H5B...|  562|
# UCHJCZ2QUD-WAJTGi...|  519|
# UCsgEkEWaXKQwrhlL...|  517|
# UCBE7ZWLXtk3WfH7x...|  446|
# UCVTL2ER5zYnZLkoq...|  439|
# UC2GK1jS6xrYTh4Xo...|  435|
# UCrlNi8Z5TXfWJf4p...|  417|
# UC7kI8WjpCfFoMSND...|  414|
# UCN4BoFTD9YncU-Np...|  390|
# UC4rasfm9J-X4jNl9...|  374|
# UCNTngyvySnbzUdV1...|  361|
# UC0iwHRFpv2_fpojZ...|  348|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+-----+
# snippet_channelTitle|count|
# +--------------------+-----+
#            Prisoneer| 1060|
#      Majestic Casual|  871|
#                 HATE|  854|
#       MrSuicideSheep|  852|
#          Boiler Room|  839|
#                 KEXP|  824|
#     Spinnin&#39; Records|  793|
#     1theK (원더케이)|  579|
#           7296272962|  562|
#                DLoaw|  519|
#              Sub Pop|  518|
#      Les Yeux Orange|  457|
#           Fuccyootoo|  446|
#              Okmusix|  439|
#             Gazzz696|  435|
#   Délicieuse Musique|  417|
#            Pitchfork|  414|
#               HHVIBE|  390|
#          Ultra Music|  374|
#          MineurDuSon|  361|
# +--------------------+-----+
# only showing top 20 rows
#
# +----------------------------+------+
# snippet_defaultAudioLanguage| count|
# +----------------------------+------+
#                         null|479300|
#                        en-US| 16109|
#                           en|  8568|
#                           fr|  2519|
#                        en-GB|  2099|
#                          zxx|   803|
#                           ko|   459|
#                           ja|   405|
#                           hi|   298|
#                           es|   267|
#                       es-419|   245|
#                           ar|   161|
#                           pt|   128|
#                           de|   119|
#                           it|    92|
#                           iw|    92|
#                           ru|    89|
#                        pt-PT|    75|
#                           nl|    61|
#                        fr-CA|    60|
# +----------------------------+------+
# only showing top 20 rows
#
# +-----------------------+------+
# snippet_defaultLanguage| count|
# +-----------------------+------+
#                    null|509033|
#                      en|  2148|
#                      fr|   419|
#                   en-GB|   301|
#                      ja|   141|
#                   en-US|   137|
#                      ko|    70|
#                      es|    56|
#                      iw|    47|
#                  es-419|    34|
#                      ru|    28|
#                   pt-PT|    28|
#                      pt|    25|
#                      ar|    20|
#                   fr-CA|    20|
#                      de|    14|
#                      pl|    14|
#                      tr|    13|
#                      it|    13|
#                   zh-TW|     7|
# +-----------------------+------+
# only showing top 20 rows
#
# +----------------------------+------+
# snippet_liveBroadcastContent| count|
# +----------------------------+------+
#                         none|512622|
#                         live|     2|
# +----------------------------+------+
#
# +--------------------+-----+
#  snippet_publishedAt|count|
# +--------------------+-----+
# 2014-09-24T10:51:...|   24|
# 2014-01-14T18:11:...|   20|
# 2014-09-18T21:04:...|   19|
# 2014-09-18T12:46:...|   18|
# 2014-07-25T13:51:...|   15|
# 2013-09-10T21:28:...|   14|

# %% [markdown]
# Next part will be done for you, because this is **tedious**, in case you didn't notice, data science is mostly about doing "boring" stuff and _sometimes_ do cool stuff... 😅
# Today, it's on us, but do not skim on these kind of tasks in your projects, **taking the time to see and understand your data is primordial**.
#
# We do it for you, but it's nice that you understand. Here's the process:
# First, for convenience, we create an [Enum](https://docs.python.org/3/library/enum.html#module-enum) with 4 attributes:
# - `'not selected'`: this is not our priority, we won't use this column
# - `'selected'`: this looks interesting, we will use this column for our next analysis
# - `'maybe'`: unsure about this one, maybe for a second pass
# - `'later'`: this is interesting, but not prioritary or time-comsuming, we will come back to this later

# %%
from enum import Enum

class Status(Enum):
  NOT_SELECTED = 'not selected'
  SELECTED = 'selected'
  LATER = 'later'
  MAYBE = 'maybe'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# In the following cells, we took a look at the `.show()` statements showing the value counts for each columns.
# As we take note, we keep track of which selection we make for each column. We told you, **it is tedious work**.

# %% [markdown]
# ### contentDetails
#
# #### `contentDetails_caption`
# Most values are `false` => NOT SELECTED
#
# #### `contentDetails_contentRating_ytRating`
# Apparently, this column seems to indicate if the content is restricted in any way, in particular if it is age restricted.
# Most value are not restricted => NOT SELECTED
#
# #### `contentDetails_definition`
# This is the definition of the video, either `sd` (low def) or `hd` (high-def) => NOT SURE YET
#
# #### `contentDetails_dimension`
# Apparently, it is to indicate if the content is using 2Dimension (`2d`) or 3Dimension (`3d`).
# Almost all videos are 2-dimensions. => NOT SELECTED
#
# #### `contentDetails_duration`
# ISO8601 encoded duration of the song, obviously many different values, plus that's interesting => SELECTED
#
# #### `contentDetails_licensedContent`
# Boolean: more false than true, not sure it's interesting => NOT SURE YET
#
# #### `contentDetails_projection`
# 2 values, either `rectangular` or `360`, I guess it's either standard video or like Virtual Reality stuff, almost all are `rectangular` => NOT SELECTED

# %% [markdown]
# ### Misc
#
# #### `etag`
# Unique values. I think it's related to Youtube API, plus we got the `id` in another column => NOT SELECTED
#
# #### `id`
# Unique values, unique `id` in Youtube. We'll need this to join with our logs. => SELECTED
#
# #### `kind`
# Only one unique value: `youtube#video`. => NOT SELECTED

# %% [markdown]
# ### Snippet
#
# #### `snippet_categoryId`
# Seems to indicate the category ID (within Youtube), most values are 10 (most likely means 'music').
# Could be interesting. => MAYBE SELECTED
#
# #### `snippet_channelId`
# The id of the youtube channel the video belongs to, could be interesting to know if some channels are more popular and if users tend to listen to songs from the same channels.  => SELECTED
#
# #### `snippet_channelTitle`
# The title of the channel. Will be useful in combo with `channelId` to perform analysis. => SELECTED
#
# #### `snippet_defaultAudioLanguage`
# The default audio language of the video. Most values are `null`. => LATER
#
# #### `snippet_defaultLanguage`
# The default language of the video. Most values are `null`. => LATER
#
# #### `snippet_description`
# The description of the video as text content. This is text content. => LATER
#
# #### `snippet_liveBroadcastContent`
# Tells if the video was a live broadcast or not. Almost none are. => NOT SELECTED
#
# #### `snippet_localized_description`
# Localized version of the description. Similar to `snippet_description`. => NOT SELECTED
#
# #### `snippet_localized_title`
# The localized title. => MAYBE
#
# #### `snippet_publishedAt`
# Date of publication of the video. That's very interesting. => SELECTED
#
# #### `snippet_thumbnails_default_height`
# Height of the image thumbnails. One unique value. => NOT SELECTED
#
# #### `snippet_thumbnails_default_url`
# URLs of the thumbnails images. Only unique values, although some substring might not be unique, we won't dig into this for the moment. => NOT SELECTED
#
# #### `snippet_thumbnails_default_width`
# Similar to `snippet_thumbnails_default_height`. One unique value. => NOT SELECTED
#
# #### `snippet_thumbnails_high_height`
# Probably similar to `snippet_thumbnails_default_height` and `snippet_thumbnails_high_height`.
# One unique value. => NOT SELECTED
#
# #### `snippet_thumbnails_high_url`
# Similar to `snippet_thumbnails_default_url`. => NOT SELECTED
#
# #### `snippet_thumbnails_high_width`
# Similar to all other dimensions values of the thumbnails image. => NOT SELECTED
#
# #### `snippet_thumbnails_maxres_height`
# Similar to other dimensions values of the thumbnails, this one is a bit different as it has half of missing values.
# Not selecting now but the missing values could capture some time dependant signal (that we might already get from `snippet_publishedAt`). => NOT SELECTED
#
# #### `snippet_thumbnails_maxres_url`
# Same amount of null values as `snippet_thumbnails_maxres_height`, which, kinda makes sense. => NOT SELECTED
#
# #### `snippet_thumbnails_maxres_width`
# Same amount of null values as `snippet_thumbnails_maxres_height` and `snippet_thumbnails_maxres_url`. => NOT SELECTED
#
# #### `snippet_thumbnails_medium_height`
# Same as other thumbnails dimensions. => NOT SELECTED
#
# #### `snippet_thumbnails_medium_url`
# Same as other thumbnails URLs => NOT SELECTED
#
# #### `snippet_thumbnails_medium_width`
# Same as other thumbnails dimensions. => NOT SELECTED
#
# #### `snippet_thumbnails_standard_height`
# Related to thumbnails standard, some missing values. => NOT SELECTED
#
# #### `snippet_thumbnails_standard_url`
# URLs for standard thumbails, shares the same amout of missing values as `snippet_thumbnails_standard_height`. => NOT SELECTED
#
# #### `snippet_thumbnails_standard_width`
# Width for standard thumbails. Missing values amount checks out. => NOT SELECTED
#
# #### `snippet_title`
# Text content, will be useful for analysis. => SELECTED

# %% [markdown]
# ### Statistics
#
# #### `statistics_commentCount`
# Count of comments on the video. => SELECTED
#
# #### `statistics_dislikeCount`
# Count of dislikes on the video => SELECTED
#
# #### `statistics_favoriteCount`
# Count of favorites on the video. That could be of interest, but only one unique value `0`. => NOT SELECTED
#
# #### `statistics_viewCount`
# View counts on the video. => SELECTED

# %% [markdown]
# ### Status
#
# #### `status_embeddable`
# Is it embeddable or not, I'm not really sure what it means, we can dig out later. => LATER
#
# #### `status_license`
# License of the content, either `youtube` or `creativeCommon`. Most are `youtube`. => LATER
#
# #### `status_privacyStatus`
# Wether the video is `public`, public but `unlisted` or probably `private`. We only have values for the first twos. Most are `public`. => LATER
#
# #### `status_publicStatsViewable`
# Are the stats publicly viewable (boolean), most are `true`. => LATER
#
# #### `status_uploadStatus`
# Either `processed` or `uploaded`. Almost all are `processed`. => NOT SELECTED
#
# ####

# %% [markdown]
# Now, we're going to store our results as a pandas DataFrame.
# We create a Python's dictionary which keys are the name of the columns, and values are values of one of the 4 options in our `Enum`.

# %%
selection_dict = {
  'contentDetails_caption': Status.NOT_SELECTED,
  'contentDetails_contentRating_ytRating': Status.NOT_SELECTED,
  'contentDetails_definition': Status.MAYBE,
  'contentDetails_dimension': Status.NOT_SELECTED,
  'contentDetails_duration': Status.SELECTED,
  'contentDetails_licensedContent': Status.MAYBE,
  'contentDetails_projection': Status.NOT_SELECTED,
  'etag': Status.NOT_SELECTED,
  'id': Status.SELECTED,
  'kind': Status.NOT_SELECTED,
  'snippet_categoryId': Status.MAYBE,
  'snippet_channelId': Status.SELECTED,
  'snippet_channelTitle': Status.SELECTED,
  'snippet_defaultAudioLanguage': Status.LATER,
  'snippet_defaultLanguage': Status.LATER,
  'snippet_description': Status.LATER,
  'snippet_liveBroadcastContent': Status.NOT_SELECTED,
  'snippet_localized_description': Status.NOT_SELECTED,
  'snippet_localized_title': Status.LATER,
  'snippet_publishedAt': Status.SELECTED,
  'snippet_thumbnails_default_height': Status.NOT_SELECTED,
  'snippet_thumbnails_default_url': Status.NOT_SELECTED,
  'snippet_thumbnails_default_width': Status.NOT_SELECTED,
  'snippet_thumbnails_high_height': Status.NOT_SELECTED,
  'snippet_thumbnails_high_url': Status.NOT_SELECTED,
  'snippet_thumbnails_high_width': Status.NOT_SELECTED,
  'snippet_thumbnails_maxres_height': Status.NOT_SELECTED,
  'snippet_thumbnails_maxres_url': Status.NOT_SELECTED,
  'snippet_thumbnails_maxres_width': Status.NOT_SELECTED,
  'snippet_thumbnails_medium_height': Status.NOT_SELECTED,
  'snippet_thumbnails_medium_url': Status.NOT_SELECTED,
  'snippet_thumbnails_medium_width': Status.NOT_SELECTED,
  'snippet_thumbnails_standard_height': Status.NOT_SELECTED,
  'snippet_thumbnails_standard_url': Status.NOT_SELECTED,
  'snippet_thumbnails_standard_width': Status.NOT_SELECTED,
  'snippet_title': Status.SELECTED,
  'statistics_commentCount': Status.SELECTED,
  'statistics_dislikeCount': Status.SELECTED,
  'statistics_favoriteCount': Status.NOT_SELECTED,
  'statistics_viewCount': Status.SELECTED,
  'status_embeddable': Status.LATER,
  'status_license': Status.LATER,
  'status_privacyStatus': Status.LATER,
  'status_publicStatsViewable': Status.LATER,
  'status_uploadStatus': Status.NOT_SELECTED
}

import pandas as pd

selection_df = pd.DataFrame.from_dict({k: v.value for k, v in selection_dict.items()},
                                      orient='index', columns=['status'])
selection_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>contentDetails_caption</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>contentDetails_contentRating_ytRating</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>contentDetails_definition</th>
#       <td>maybe</td>
#     </tr>
#     <tr>
#       <th>contentDetails_dimension</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>contentDetails_duration</th>
#       <td>selected</td>
#     </tr>
#     <tr>
#       <th>contentDetails_licensedContent</th>
#       <td>maybe</td>
#     </tr>
#     <tr>
#       <th>contentDetails_projection</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>etag</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>id</th>
#       <td>selected</td>
#     </tr>
#     <tr>
#       <th>kind</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_categoryId</th>
#       <td>maybe</td>
#     </tr>
#     <tr>
#       <th>snippet_channelId</th>
#       <td>selected</td>
#     </tr>
#     <tr>
#       <th>snippet_channelTitle</th>
#       <td>selected</td>
#     </tr>
#     <tr>
#       <th>snippet_defaultAudioLanguage</th>
#       <td>later</td>
#     </tr>
#     <tr>
#       <th>snippet_defaultLanguage</th>
#       <td>later</td>
#     </tr>
#     <tr>
#       <th>snippet_description</th>
#       <td>later</td>
#     </tr>
#     <tr>
#       <th>snippet_liveBroadcastContent</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_localized_description</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_localized_title</th>
#       <td>later</td>
#     </tr>
#     <tr>
#       <th>snippet_publishedAt</th>
#       <td>selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_default_height</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_default_url</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_default_width</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_high_height</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_high_url</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_high_width</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_maxres_height</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_maxres_url</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_maxres_width</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_medium_height</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_medium_url</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_medium_width</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_standard_height</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_standard_url</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_thumbnails_standard_width</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>snippet_title</th>
#       <td>selected</td>
#     </tr>
#     <tr>
#       <th>statistics_commentCount</th>
#       <td>selected</td>
#     </tr>
#     <tr>
#       <th>statistics_dislikeCount</th>
#       <td>selected</td>
#     </tr>
#     <tr>
#       <th>statistics_favoriteCount</th>
#       <td>not selected</td>
#     </tr>
#     <tr>
#       <th>statistics_viewCount</th>
#       <td>selected</td>
#     </tr>
#     <tr>
#       <th>status_embeddable</th>
#       <td>later</td>
#     </tr>
#     <tr>
#       <th>status_license</th>
#       <td>later</td>
#     </tr>
#     <tr>
#       <th>status_privacyStatus</th>
#       <td>later</td>
#     </tr>
#     <tr>
#       <th>status_publicStatsViewable</th>
#       <td>later</td>
#     </tr>
#     <tr>
#       <th>status_uploadStatus</th>
#       <td>not selected</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# We'll check how many of each tag we got.

# %%
selection_df \
  .groupby('status') \
  .agg({'status': 'count'}) \
  .rename(columns={'status': 'count'})
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>status</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>later</th>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>maybe</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>not selected</th>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>selected</th>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# We only selected 9 columns from the 46 we had at the beginning. This should makes thing easier to analyze.

# %%
# TODO: Get the selected columns as a list: `selected_columns`
### BEGIN STRIP ###

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: [&#39;contentDetails_duration&#39;,
#  &#39;id&#39;,
#  &#39;snippet_channelId&#39;,
#  &#39;snippet_channelTitle&#39;,
#  &#39;snippet_publishedAt&#39;,
#  &#39;snippet_title&#39;,
#  &#39;statistics_commentCount&#39;,
#  &#39;statistics_dislikeCount&#39;,
#  &#39;statistics_viewCount&#39;]</div>

# %%
# TODO: Select the `selected_columns` from `songs_raw`: `songs`
#       Then, print out:
#       - the schema of the dataframe
#       - the shape of the DataFrame, e.g. the number of rows and columns
### BEGIN STRIP ###

### END STRIP ###
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- contentDetails_duration: string (nullable = true)
# -- id: string (nullable = true)
# -- snippet_channelId: string (nullable = true)
# -- snippet_channelTitle: string (nullable = true)
# -- snippet_publishedAt: string (nullable = true)
# -- snippet_title: string (nullable = true)
# -- statistics_commentCount: long (nullable = true)
# -- statistics_dislikeCount: long (nullable = true)
# -- statistics_viewCount: long (nullable = true)
#
# Shape:  (512624, 9)
# </div>
